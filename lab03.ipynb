# %% [markdown]
# <a href="https://colab.research.google.com/github/diegofuentes51/LAB03MINERIA/blob/main/lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"
data = pd.read_csv(url)
data
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
data = pd.read_csv(url, names=["buying", "maint", "doors", "persons", "lug_boot", "safety", "acceptability"])
data
# Out:
#      buying  maint  doors persons lug_boot safety acceptability
# 0     vhigh  vhigh      2       2    small    low         unacc
# 1     vhigh  vhigh      2       2    small    med         unacc
# 2     vhigh  vhigh      2       2    small   high         unacc
# 3     vhigh  vhigh      2       2      med    low         unacc
# 4     vhigh  vhigh      2       2      med    med         unacc
# ...     ...    ...    ...     ...      ...    ...           ...
# 1723    low    low  5more    more      med    med          good
# 1724    low    low  5more    more      med   high         vgood
# 1725    low    low  5more    more      big    low         unacc
# 1726    low    low  5more    more      big    med          good
# 1727    low    low  5more    more      big   high         vgood
#
# [1728 rows x 7 columns]

# %%
# Extraer columnas
list(data)
list(data.columns)
data.columns.tolist()
list(data.columns.values)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
# Medición del rendimiento
from timeit import timeit

t1 = timeit(lambda: list(data))
t2 = timeit(lambda: list(data.columns))
t3 = timeit(lambda: data.columns.tolist())
t4 = timeit(lambda: list(data.columns.values))

print(t1, t2, t3, t4)
# Out:
# 2.0960168050000334 2.009299980000037 0.6874859089999745 1.6612658710000119

# %%
data['buying'].dtype
data['persons'].dtype
data.dtypes
# Out:
# buying           object
# maint            object
# doors            object
# persons          object
# lug_boot         object
# safety           object
# acceptability    object
# dtype: object

# %%
data["doors"].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
# Cambiando tipo de datos
data['doors'] = data['doors'].astype('category')
data['persons'] = data['persons'].astype('category')

data.dtypes
# Out:
# buying             object
# maint              object
# doors            category
# persons          category
# lug_boot           object
# safety             object
# acceptability      object
# dtype: object

# %%
# Cambiando nombre a categorías
import numpy as np

data["lug_boot"] = np.where(data["lug_boot"] == "small", "pequeño", data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"] == "med", "mediano", data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"] == "big", "grande", data["lug_boot"])

data["lug_boot"].unique()
# Out:
# array(['pequeño', 'mediano', 'grande'], dtype=object)

# %%
data.rename({'lug_boot': 'trunk'}, axis=1, inplace=True)
data
# Out:
#      buying  maint  doors persons    trunk safety acceptability
# 0     vhigh  vhigh      2       2  pequeño    low         unacc
# 1     vhigh  vhigh      2       2  pequeño    med         unacc
# 2     vhigh  vhigh      2       2  pequeño   high         unacc
# 3     vhigh  vhigh      2       2  mediano    low         unacc
# 4     vhigh  vhigh      2       2  mediano    med         unacc
# ...     ...    ...    ...     ...      ...    ...           ...
# 1723    low    low  5more    more  mediano    med          good
# 1724    low    low  5more    more  mediano   high         vgood
# 1725    low    low  5more    more   grande    low         unacc
# 1726    low    low  5more    more   grande    med          good
# 1727    low    low  5more    more   grande   high         vgood
#
# [1728 rows x 7 columns]

# %%
data.shape

data.head()

data.tail()
# Out:
#      buying maint  doors persons    trunk safety acceptability
# 1723    low   low  5more    more  mediano    med          good
# 1724    low   low  5more    more  mediano   high         vgood
# 1725    low   low  5more    more   grande    low         unacc
# 1726    low   low  5more    more   grande    med          good
# 1727    low   low  5more    more   grande   high         vgood

# %%
# Segmentación de filas y columnas
data.iloc[0:3, 1:4]
# Out:
#    maint doors persons
# 0  vhigh     2       2
# 1  vhigh     2       2
# 2  vhigh     2       2

# %%
data.loc[[0, 10], :]
# Out:
#    buying  maint doors persons    trunk safety acceptability
# 0   vhigh  vhigh     2       2  pequeño    low         unacc
# 10  vhigh  vhigh     2       4  pequeño    med         unacc

# %%
data.loc[0:20, ['doors', 'persons']]
# Out:
#    doors persons
# 0      2       2
# 1      2       2
# 2      2       2
# 3      2       2
# 4      2       2
# 5      2       2
# 6      2       2
# 7      2       2
# 8      2       2
# 9      2       4
# 10     2       4
# 11     2       4
# 12     2       4
# 13     2       4
# 14     2       4
# 15     2       4
# 16     2       4
# 17     2       4
# 18     2    more
# 19     2    more
# 20     2    more

# %%
data[data.buying == "vhigh"]
# Out:
#     buying  maint  doors persons    trunk safety acceptability
# 0    vhigh  vhigh      2       2  pequeño    low         unacc
# 1    vhigh  vhigh      2       2  pequeño    med         unacc
# 2    vhigh  vhigh      2       2  pequeño   high         unacc
# 3    vhigh  vhigh      2       2  mediano    low         unacc
# 4    vhigh  vhigh      2       2  mediano    med         unacc
# ..     ...    ...    ...     ...      ...    ...           ...
# 427  vhigh    low  5more    more  mediano    med           acc
# 428  vhigh    low  5more    more  mediano   high           acc
# 429  vhigh    low  5more    more   grande    low         unacc
# 430  vhigh    low  5more    more   grande    med           acc
# 431  vhigh    low  5more    more   grande   high           acc
#
# [432 rows x 7 columns]

# %%
data[(data.safety == "med") | (data.safety == "high")]
# Out:
#      buying  maint  doors persons    trunk safety acceptability
# 1     vhigh  vhigh      2       2  pequeño    med         unacc
# 2     vhigh  vhigh      2       2  pequeño   high         unacc
# 4     vhigh  vhigh      2       2  mediano    med         unacc
# 5     vhigh  vhigh      2       2  mediano   high         unacc
# 7     vhigh  vhigh      2       2   grande    med         unacc
# ...     ...    ...    ...     ...      ...    ...           ...
# 1721    low    low  5more    more  pequeño   high          good
# 1723    low    low  5more    more  mediano    med          good
# 1724    low    low  5more    more  mediano   high         vgood
# 1726    low    low  5more    more   grande    med          good
# 1727    low    low  5more    more   grande   high         vgood
#
# [1152 rows x 7 columns]

# %%
data.to_csv('car_data.csv', index=False)
